# %%
# Introduction
print("Hello Welcome To The Vishwa Calculator")
print("--------------------------------------------------")
# Get the numbers
print("Enter Your first Number")
num1 = int(input())
print("--------------------------------------------------")
print("Enter Your Second Number")
num2 = int(input())
print("--------------------------------------------------")
# Get the operation
print("Enter Your Operation add sub mul or div or sqr or avg or cube")
opp = str(input())

# function - ADD operation
def add(num1,num2):
    result = num1 + num2
    return result

# function - MUL operation
def mul(num1,num2):
    result = num1 * num2 
    return result

# function - SUB operation
def sub(num1,num2):
    result = num1 - num2
    return result

# function - DIV operation
def div(num1,num2):
    result = num1 / num2
    return result

# function - SQR operation
def sqr(num1):
    result = num1 * num1
    return result

#function - AVG operation
def avg(num1,num2):
    result = num1 + num2 /2
    return result

#function - CUBE operation
def cube(num1):
    result = num1 * num1 * num1
    return result


#Check condition ADD
if opp == "add":
    result = add(num1,num2)
    
    
#Check condition MUL    
if opp == "mul":
    result = mul(num1,num2)
    

#Check condition SUB
if opp == "sub":
    result = sub(num1,num2)
    

#Check condition DIV    
if opp == "div":
    result = div(num1,num2)
    
    
#Check condition SQR    
if opp == "sqr":
    result = sqr(num1)
    
    
#Check condition AVG
if opp == "avg":
    result = avg(num1,num2)
    
#Check condition CUBE
if opp == "cube":
    result = cube(num1)
#Tell The User The Answer    
print("Your Answer is",result)
print("--------------------------------------------------------")
#Thank The User For Using The Calculator
print("Thank You For Using The Vishwa Calculator")
