# %%
#Welcoming The User
print("Welcome To The Ultimate Converter")

#Asking The User To Enter A Conversion
print("Enter A Conversion Ex F2C,C2F,K2P,P2K,M2K,K2M")
typeofconv = str(input())

#Asking The User To Enter A Number
print("Enter A Number")
inputnum = int(input())



#function - FAREN2CELCIUS conversion
def faren2celcius(num):
    result = 5/9 * num - 32
    return result



#function - CELCIUS2FAREN conversion
def celcius2faren(num):
    result = 9/5 * num + 32
    return result



#function - KILLOS2POUNDS conversion
def killos2pounds(num):
    result = num * 2.2
    return result



#function - POUNDS2KILLOS conversion
def pounds2killos(num):
    result = num / 2.2
    return result



#function - MILE2KILLOMETER conversion
def mile2killometer(num):
    result = num * 1.6
    return result



#function - KILLOMETER2MILE CONVERSION
def killometer2mile(num):
    result = num / 1.6
    return result




# Check Condition - F2C
if typeofconv == "F2C":
    result = faren2celcius(inputnum)
    print("This was your answer farenhiet to celcius",result)
    
    
    

#Check Condition - C2F
if typeofconv == "C2F":
    result = celcius2faren(inputnum)
    print("This was your answer celcius to farenhiet",result)

    



#Check Condition - K2P
if typeofconv == "K2P":
    result = killos2pounds(inputnum)
    print("This was your answer killograms to pounds",result)
    
    
    


#Check Condition - P2K   
if typeofconv == "P2K":
    result = pounds2killos(inputnum)
    print("This was your answer pounds to killograms",result)
    
    


    
#Check Condition - M2K
if typeofconv == "M2K":
    result = mile2killometer(inputnum)
    print("This was your answer miles to killometer",result)
    

    
    
    
#Check Condition - K2M
if typeofconv == "K2M":
    result = kilometer2mile(inputnum)
    print("This was your answer killometer to miles",result)
    

#Sign Off And Tell The User Thank You 
print("Thank You For Using The Ultimate Converter")
# Out:
# Welcome To The Ultimate Converter
# Enter A Conversion Ex F2C,C2F,K2P,P2K,M2K,K2M
# K2P
# Enter A Number
# 50
# This was your answer killograms to pounds 110.00000000000001
# Thank You For Using The Ultimate Converter
